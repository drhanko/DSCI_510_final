# %%
import pandas as pd
from datasets import load_dataset

# %% [markdown]
# ## empathetic_dialogues

# %%
empathetic_dialogues = load_dataset("empathetic_dialogues",trust_remote_code=True)
print("1")
print(empathetic_dialogues)
# Out:
# Downloading readme: 0.00B [00:00, ?B/s]
# 1
# DatasetDict({
#     train: Dataset({
#         features: ['conv_id', 'utterance_idx', 'context', 'prompt', 'speaker_idx', 'utterance', 'selfeval', 'tags'],
#         num_rows: 76673
#     })
#     validation: Dataset({
#         features: ['conv_id', 'utterance_idx', 'context', 'prompt', 'speaker_idx', 'utterance', 'selfeval', 'tags'],
#         num_rows: 12030
#     })
#     test: Dataset({
#         features: ['conv_id', 'utterance_idx', 'context', 'prompt', 'speaker_idx', 'utterance', 'selfeval', 'tags'],
#         num_rows: 10943
#     })
# })

# %%
empathetic_dialogues
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['conv_id', 'utterance_idx', 'context', 'prompt', 'speaker_idx', 'utterance', 'selfeval', 'tags'],
#         num_rows: 76673
#     })
#     validation: Dataset({
#         features: ['conv_id', 'utterance_idx', 'context', 'prompt', 'speaker_idx', 'utterance', 'selfeval', 'tags'],
#         num_rows: 12030
#     })
#     test: Dataset({
#         features: ['conv_id', 'utterance_idx', 'context', 'prompt', 'speaker_idx', 'utterance', 'selfeval', 'tags'],
#         num_rows: 10943
#     })
# })

# %%
rows = []

for item in empathetic_dialogues["train"]:
    rows.append({
        "dataset": "empathetic_dialogues",
        "conversation_id": item["conv_id"],
        "role": "user" if item["speaker_idx"] == 0 else "assistant",
        "text": item["utterance"],
        "emotion": item["context"]
    })

df_empathetic = pd.DataFrame(rows)
# df_empathetic.to_csv("empathetic_dialogues.csv", index=False)
df_empathetic_train
# Out:
#                     dataset       conversation_id       role  \
# 0      empathetic_dialogues          hit:0_conv:1  assistant
# 1      empathetic_dialogues          hit:0_conv:1       user
# 2      empathetic_dialogues          hit:0_conv:1  assistant
# 3      empathetic_dialogues          hit:0_conv:1       user
# 4      empathetic_dialogues          hit:0_conv:1  assistant
# ...                     ...                   ...        ...
# 76668  empathetic_dialogues  hit:12424_conv:24848  assistant
# 76669  empathetic_dialogues  hit:12424_conv:24849  assistant
# 76670  empathetic_dialogues  hit:12424_conv:24849  assistant
# 76671  empathetic_dialogues  hit:12424_conv:24849  assistant
# 76672  empathetic_dialogues  hit:12424_conv:24849  assistant
#
#                                                     text      emotion
# 0      I remember going to see the fireworks with my ...  sentimental
# 1      Was this a friend you were in love with_comma_...  sentimental
# 2                    This was a best friend. I miss her.  sentimental
# 3                                    Where has she gone?  sentimental
# 4                                     We no longer talk.  sentimental
# ...                                                  ...          ...
# 76668  Yeah reminds me of the good old days.  I miss ...  sentimental
# 76669  I woke up this morning to my wife telling me s...    surprised
# 76670     Oh hey that's awesome!  That is awesome right?    surprised
# 76671  It is soooo awesome.  We have been wanting a b...    surprised
# 76672               That is awesome!!!! Congratulations!    surprised
#
# [76673 rows x 5 columns]

# %% [markdown]
# ## Daily_dialog

# %%
daily_dialog = load_dataset("roskoN/dailydialog",trust_remote_code=True,download_mode="force_redownload")
print("2")
print(daily_dialog)
# Out:
# Downloading data: 100%|████████████████████| 3.67M/3.67M [00:00<00:00, 4.75MB/s]
# Downloading data: 100%|██████████████████████| 340k/340k [00:00<00:00, 1.14MB/s]
# Downloading data: 100%|██████████████████████| 337k/337k [00:00<00:00, 1.33MB/s]
# Generating train split:   0%|          | 0/11118 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/1000 [00:00<?, ? examples/s]
# 2
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'acts', 'emotions', 'utterances'],
#         num_rows: 11118
#     })
#     validation: Dataset({
#         features: ['id', 'acts', 'emotions', 'utterances'],
#         num_rows: 1000
#     })
#     test: Dataset({
#         features: ['id', 'acts', 'emotions', 'utterances'],
#         num_rows: 1000
#     })
# })

# %%
print(daily_dialog['train'][0])
# Out:
# {'id': 'a438b751ab9997cdb35f07bfe3dfb010b96365f4762d77f87e5f41290ff61c3d_0', 'acts': [3, 4, 2, 2, 2, 3, 4, 1, 3, 4], 'emotions': [0, 0, 0, 0, 0, 0, 4, 4, 4, 4], 'utterances': ['Say , Jim , how about going for a few beers after dinner ?', 'You know that is tempting but is really not good for our fitness .', 'What do you mean ? It will help us to relax .', "Do you really think so ? I don't . It will just make us fat and act silly . Remember last time ?", "I guess you are right.But what shall we do ? I don't feel like sitting at home .", 'I suggest a walk over to the gym where we can play singsong and meet some of our friends .', "That's a good idea . I hear Mary and Sally often go there to play pingpong.Perhaps we can make a foursome with them .", 'Sounds great to me ! If they are willing , we could ask them to go dancing with us.That is excellent exercise and fun , too .', "Good.Let ' s go now .", 'All right .']}

# %%
rows = []

for idx, item in enumerate(daily_dialog["train"]):
        rows.append({
            "dataset": "daily_dialog",
            "conversation_id": item['id'],
            "acts": item['acts'],
            "text": item['utterances'],
            "emotion": item["emotions"]
        })

df_daily = pd.DataFrame(rows)
df_daily
# df_daily.to_csv("daily_dialog.csv", index=False)
# Out:
#             dataset                                    conversation_id  \
# 0      daily_dialog  a438b751ab9997cdb35f07bfe3dfb010b96365f4762d77...
# 1      daily_dialog  a438b751ab9997cdb35f07bfe3dfb010b96365f4762d77...
# 2      daily_dialog  a438b751ab9997cdb35f07bfe3dfb010b96365f4762d77...
# 3      daily_dialog  a438b751ab9997cdb35f07bfe3dfb010b96365f4762d77...
# 4      daily_dialog  a438b751ab9997cdb35f07bfe3dfb010b96365f4762d77...
# ...             ...                                                ...
# 11113  daily_dialog  a438b751ab9997cdb35f07bfe3dfb010b96365f4762d77...
# 11114  daily_dialog  a438b751ab9997cdb35f07bfe3dfb010b96365f4762d77...
# 11115  daily_dialog  a438b751ab9997cdb35f07bfe3dfb010b96365f4762d77...
# 11116  daily_dialog  a438b751ab9997cdb35f07bfe3dfb010b96365f4762d77...
# 11117  daily_dialog  a438b751ab9997cdb35f07bfe3dfb010b96365f4762d77...
#
#                                                    acts  \
# 0                        [3, 4, 2, 2, 2, 3, 4, 1, 3, 4]
# 1                                    [2, 1, 2, 2, 1, 1]
# 2                                       [2, 1, 2, 1, 1]
# 3                                          [2, 1, 1, 1]
# 4                           [2, 1, 2, 1, 1, 2, 1, 3, 4]
# ...                                                 ...
# 11113                       [1, 1, 1, 2, 3, 2, 1, 4, 1]
# 11114                                [2, 1, 2, 1, 3, 4]
# 11115  [2, 1, 2, 1, 1, 1, 1, 1, 2, 1, 2, 1, 2, 1, 3, 4]
# 11116                                      [2, 3, 4, 3]
# 11117                                            [3, 4]
#
#                                                     text  \
# 0      [Say , Jim , how about going for a few beers a...
# 1      [Can you do push-ups ?, Of course I can . It's...
# 2      [Can you study with the radio on ?, No , I lis...
# 3      [Are you all right ?, I will be all right soon...
# 4      [Hey John , nice skates . Are they new ?, Yeah...
# ...                                                  ...
# 11113  [Hello , I bought a pen in your shop just befo...
# 11114  [Do you have any seats available ?, Yes . This...
# 11115  [Uncle Ben , how did the Forbidden City get th...
# 11116  [May I help you , sir ?, I want a pair of locu...
# 11117  [Could I have the check , please ?, Okay . I'l...
#
#                                                 emotion
# 0                        [0, 0, 0, 0, 0, 0, 4, 4, 4, 4]
# 1                                    [0, 0, 6, 0, 0, 0]
# 2                                       [0, 0, 0, 0, 0]
# 3                                          [0, 0, 0, 0]
# 4                           [0, 0, 0, 0, 0, 6, 0, 6, 0]
# ...                                                 ...
# 11113                       [0, 4, 0, 0, 0, 0, 0, 0, 4]
# 11114                                [0, 0, 0, 0, 0, 4]
# 11115  [0, 0, 6, 0, 6, 0, 0, 0, 0, 0, 0, 0, 0, 0, 4, 0]
# 11116                                      [0, 0, 0, 0]
# 11117                                            [0, 0]
#
# [11118 rows x 5 columns]

# %% [markdown]
# ## GoEmotions

# %%
go_emotions = load_dataset("go_emotions",trust_remote_code=True)
print("3")
print(go_emotions)
# Out:
# Downloading readme: 0.00B [00:00, ?B/s]
# 3
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'labels', 'id'],
#         num_rows: 43410
#     })
#     validation: Dataset({
#         features: ['text', 'labels', 'id'],
#         num_rows: 5426
#     })
#     test: Dataset({
#         features: ['text', 'labels', 'id'],
#         num_rows: 5427
#     })
# })

# %%
print(go_emotions["train"][0])
# Out:
# {'text': "My favourite food is anything I didn't have to cook myself.", 'labels': [27], 'id': 'eebbqej'}

# %%
rows = []

for idx, item in enumerate(go_emotions["train"]):
    rows.append({
        "dataset": "go_emotions",
        "conversation_id": idx,
        "role": "user",
        "text": item["text"],
        "emotion": item["labels"]  # 這是 list，需要之後轉換
    })

df_go = pd.DataFrame(rows)
df_go
# df_go.to_csv("go_emotions.csv", index=False)
# Out:
#            dataset  conversation_id  role  \
# 0      go_emotions                0  user
# 1      go_emotions                1  user
# 2      go_emotions                2  user
# 3      go_emotions                3  user
# 4      go_emotions                4  user
# ...            ...              ...   ...
# 43405  go_emotions            43405  user
# 43406  go_emotions            43406  user
# 43407  go_emotions            43407  user
# 43408  go_emotions            43408  user
# 43409  go_emotions            43409  user
#
#                                                     text emotion
# 0      My favourite food is anything I didn't have to...    [27]
# 1      Now if he does off himself, everyone will thin...    [27]
# 2                         WHY THE FUCK IS BAYLESS ISOING     [2]
# 3                            To make her feel threatened    [14]
# 4                                 Dirty Southern Wankers     [3]
# ...                                                  ...     ...
# 43405  Added you mate well I’ve just got the bow and ...    [18]
# 43406  Always thought that was funny but is it a refe...     [6]
# 43407  What are you talking about? Anything bad that ...     [3]
# 43408            More like a baptism, with sexy results!    [13]
# 43409                                    Enjoy the ride!    [17]
#
# [43410 rows x 5 columns]
